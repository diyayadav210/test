# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('titanic.csv')

# %%
print(data)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
pd.read_csv('titanic.csv')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head(12)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
data.tail(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
survived_by_gender = data.groupby('sex')['survived'].sum()
print("survived by Gender:\n", survived_by_gender, "\n")
# Out:
# survived by Gender:
#  sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
survived = data.groupby('sex')['survived'].sum()
plt.figure(figsize=(10,6))

survived.plot(kind='bar', color='#5196D6', edgecolor='black')

plt.title("Survived by Sex")

plt.ylabel("Total Pasanger")
plt.xlabel("Sex")

plt.show()

# %%
survivedd = data['survived'].value_counts()

plt.figure(figsize=(12,8))

plt.pie(survivedd, labels=survivedd.index, autopct='%1.1f%%', startangle=140)

plt.title("Survived")

plt.show()

# %%
data.groupby(['sex','survived'])['survived'].count()
# Out:
# sex     survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))

data[['sex', 'survived']].groupby('sex').mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')

sns.countplot(x='sex', hue='survived', data=data, ax=ax[1])
ax[1].set_title('Sex : Survived vs Dead')

plt.show()

# %%
pd.crosstab(data.pclass,data.survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_f793b_row0_col0, #T_f793b_row1_col1, #T_f793b_row1_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_f793b_row0_col1 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_f793b_row0_col2 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_f793b_row1_col0 {
#   background-color: #f6fa66;
#   color: #000000;
# }
# #T_f793b_row2_col0 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_f793b_row2_col1 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_f793b_row2_col2 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_f793b_row3_col0, #T_f793b_row3_col1, #T_f793b_row3_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f793b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >survived</th>
#       <th id="T_f793b_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f793b_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['pclass'].value_counts().plot.bar(color=['#E0D972','#72E0CD','#DB7B7B'],ax=ax[0])

ax[0].set_title('Number Of Passengers By Pclass')

ax[0].set_ylabel('Count')

sns.countplot(x='pclass',hue='survived',data=data,ax=ax[1])

ax[1].set_title('pclass:survived vs Dead')

plt.show()

# %%
plt.figure(figsize=(15,10))

numeric_df = data.select_dtypes(include=['number'])
correlation_matrix = numeric_df.corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of Numeric Features")
plt.show()
